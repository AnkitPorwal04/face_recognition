# %%
import cv2

# %%
img = cv2.imread('dog.jpg')

# %%
import matplotlib.pyplot as plt

newimg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()
plt.imshow(newimg)
plt.show()

# %%
ord('a')
# Out:
# 97
